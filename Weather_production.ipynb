# %% [markdown]
# #K-Nearest Neighbour in python using scikit Learn-Symbolic

# %%
# !pip install scikit-learn
# !pip install numpy

# %%
#importing Libraries
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn import preprocessing

# %%
#loading Dataset
#Oulook,Temperature,Humidity,Windy,Play
dataset = np.array([
                    
['overcast','hot','high','FALSE','yes'],
['overcast','cool','normal','TRUE','yes'],
['overcast','mild','high','TRUE','yes'],
['overcast','hot','normal','FALSE','yes'],
['rainy','mild','high','FALSE','yes'],
['rainy','cool','normal','FALSE','yes'],
['rainy','cool','normal','TRUE','no'],
['rainy','mild','normal','FALSE','yes'],
['rainy','mild','high','TRUE','no'],
['sunny','hot','high','FALSE','no'],
['sunny','hot','high','TRUE','no'],
['sunny','mild','high','FALSE','no'],
['sunny','cool','normal','FALSE','yes'],
['sunny','mild','normal','TRUE','yes']               
])

# %%
Features=dataset[:,0:-1]
print(Features)
# Out:
# [['overcast' 'hot' 'high' 'FALSE']
#  ['overcast' 'cool' 'normal' 'TRUE']
#  ['overcast' 'mild' 'high' 'TRUE']
#  ['overcast' 'hot' 'normal' 'FALSE']
#  ['rainy' 'mild' 'high' 'FALSE']
#  ['rainy' 'cool' 'normal' 'FALSE']
#  ['rainy' 'cool' 'normal' 'TRUE']
#  ['rainy' 'mild' 'normal' 'FALSE']
#  ['rainy' 'mild' 'high' 'TRUE']
#  ['sunny' 'hot' 'high' 'FALSE']
#  ['sunny' 'hot' 'high' 'TRUE']
#  ['sunny' 'mild' 'high' 'FALSE']
#  ['sunny' 'cool' 'normal' 'FALSE']
#  ['sunny' 'mild' 'normal' 'TRUE']]

# %%
enc=preprocessing.OrdinalEncoder()
enc.fit(Features)
features=enc.transform(Features)

# %%
print(features)
# Out:
# [[0. 1. 0. 0.]
#  [0. 0. 1. 1.]
#  [0. 2. 0. 1.]
#  [0. 1. 1. 0.]
#  [1. 2. 0. 0.]
#  [1. 0. 1. 0.]
#  [1. 0. 1. 1.]
#  [1. 2. 1. 0.]
#  [1. 2. 0. 1.]
#  [2. 1. 0. 0.]
#  [2. 1. 0. 1.]
#  [2. 2. 0. 0.]
#  [2. 0. 1. 0.]
#  [2. 2. 1. 1.]]

# %%
target=dataset[:,-1]
print(target)
# Out:
# ['yes' 'yes' 'yes' 'yes' 'yes' 'yes' 'no' 'yes' 'no' 'no' 'no' 'no' 'yes'
#  'yes']

# %%
model = KNeighborsClassifier(n_neighbors=3,metric="hamming")
model.fit(features,target)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='hamming',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')

# %%
#guess
newday=np.array([["sunny","mild","high","TRUE"]])

# %%
prediction = model.predict(enc.transform(newday))

# %%
print(prediction)
# Out:
# ['no']
